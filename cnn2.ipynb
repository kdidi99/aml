# %% [markdown]
# <a href="https://colab.research.google.com/github/kdidi99/aml/blob/main/cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ConvNets with PyTorch (Exercise sheet 3)
#
# Kieran Didi, Mohammadhossein Jafari , Szymon Szmajdzinski

# %% [markdown]
# # 1 Introduction

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.optim as optim
from torch.utils.data import DataLoader

import torchvision.datasets as datasets
import torchvision.transforms as transforms

from torch.nn.functional import conv2d, max_pool2d, cross_entropy

plt.rc("figure", dpi=100)

batch_size = 100

# transform images into normalized tensors
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = datasets.MNIST(
    "./",
    download=True,
    train=True,
    transform=transform,
)

test_dataset = datasets.MNIST(
    "./",
    download=True,
    train=False,
    transform=transform,
)

train_dataloader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=1,
    pin_memory=True,
)

test_dataloader = DataLoader(
    dataset=test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=1,
    pin_memory=True,
)

def init_weights(shape):
    # Kaiming He initialization (a good initialization is important)
    # https://arxiv.org/abs/1502.01852
    std = np.sqrt(2. / shape[0])
    w = torch.randn(size=shape) * std
    w.requires_grad = True
    return w


def rectify(x):
    # Rectified Linear Unit (ReLU)
    return torch.max(torch.zeros_like(x), x)


class RMSprop(optim.Optimizer):
    """
    This is a reduced version of the PyTorch internal RMSprop optimizer
    It serves here as an example
    """
    def __init__(self, params, lr=1e-3, alpha=0.5, eps=1e-8):
        defaults = dict(lr=lr, alpha=alpha, eps=eps)
        super(RMSprop, self).__init__(params, defaults)

    def step(self):
        for group in self.param_groups:
            for p in group['params']:
                grad = p.grad.data
                state = self.state[p]

                # state initialization
                if len(state) == 0:
                    state['square_avg'] = torch.zeros_like(p.data)

                square_avg = state['square_avg']
                alpha = group['alpha']

                # update running averages
                square_avg.mul_(alpha).addcmul_(grad, grad, value=1 - alpha)
                avg = square_avg.sqrt().add_(group['eps'])

                # gradient update
                p.data.addcdiv_(grad, avg, value=-group['lr'])


# define the neural network
def model(x, w_h, w_h2, w_o):
    h = rectify(x @ w_h)
    h2 = rectify(h @ w_h2)
    pre_softmax = h2 @ w_o
    return pre_softmax


# initialize weights

# input shape is (B, 784)
w_h = init_weights((784, 625))
# hidden layer with 625 neurons
w_h2 = init_weights((625, 625))
# hidden layer with 625 neurons
w_o = init_weights((625, 10))
# output shape is (B, 10)

optimizer = RMSprop(params=[w_h, w_h2, w_o])


n_epochs = 100

train_loss = []
test_loss = []

# put this into a training loop over 100 epochs
for epoch in range(n_epochs + 1):
    train_loss_this_epoch = []
    for idx, batch in enumerate(train_dataloader):
        x, y = batch

        # our model requires flattened input
        x = x.reshape(batch_size, 784)
        # feed input through model
        noise_py_x = model(x, w_h, w_h2, w_o)

        # reset the gradient
        optimizer.zero_grad()

        # the cross-entropy loss function already contains the softmax
        loss = cross_entropy(noise_py_x, y, reduction="mean")

        train_loss_this_epoch.append(float(loss))

        # compute the gradient
        loss.backward()
        # update weights
        optimizer.step()

    train_loss.append(np.mean(train_loss_this_epoch))

    # test periodically
    if epoch % 10 == 0:
        print(f"Epoch: {epoch}")
        print(f"Mean Train Loss: {train_loss[-1]:.2e}")
        test_loss_this_epoch = []

        # no need to compute gradients for validation
        with torch.no_grad():
            for idx, batch in enumerate(test_dataloader):
                x, y = batch
                x = x.reshape(batch_size, 784)
                noise_py_x = model(x, w_h, w_h2, w_o)

                loss = cross_entropy(noise_py_x, y, reduction="mean")
                test_loss_this_epoch.append(float(loss))

        test_loss.append(np.mean(test_loss_this_epoch))

        print(f"Mean Test Loss:  {test_loss[-1]:.2e}")

plt.plot(np.arange(n_epochs + 1), train_loss, label="Train")
plt.plot(np.arange(1, n_epochs + 2, 10), test_loss, label="Test")
plt.title("Train and Test Loss over Training")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# Processing...
# Done!
# /Users/szymonszmajdzinski/opt/anaconda3/lib/python3.8/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /Users/distiller/project/conda/conda-bld/pytorch_1607370249289/work/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Epoch: 0
# Mean Train Loss: 3.93e-01
# Mean Test Loss:  1.96e-01
# Epoch: 10
# Mean Train Loss: 1.64e-01
# Mean Test Loss:  3.16e-01
# Epoch: 20
# Mean Train Loss: 1.07e-01
# Mean Test Loss:  5.25e-01
# Epoch: 30
# Mean Train Loss: 7.02e-02
# Mean Test Loss:  6.37e-01
# Epoch: 40
# Mean Train Loss: 4.73e-02
# Mean Test Loss:  6.30e-01
# Epoch: 50
# Mean Train Loss: 3.91e-02
# Mean Test Loss:  7.10e-01
# Epoch: 60
# Mean Train Loss: 1.92e-02
# Mean Test Loss:  6.90e-01
# Epoch: 70
# Mean Train Loss: 2.21e-02
# Mean Test Loss:  9.05e-01
# Epoch: 80
# Mean Train Loss: 1.99e-02
# Mean Test Loss:  8.60e-01
# Epoch: 90
# Mean Train Loss: 1.52e-02
# Mean Test Loss:  8.07e-01
# Epoch: 100
# Mean Train Loss: 1.13e-02
# Mean Test Loss:  8.98e-01

# %% [markdown]
# # 2 Dropout

# %%
def dropout(X, p_drop=0.5):
  #check that p_drop is in correct range
  assert 0 <= p_drop < 1
  if p_drop == 0:
    return X
  else:
    rng = np.random.default_rng()
    phi = rng.binomial(1, p_drop, X.shape)
    phi = phi.astype(np.float32)
    phi[phi==1] = 0
    phi[phi==0] = 1/(1-p_drop)
    X = X * torch.from_numpy(phi)
    return X

# %%
def dropout_model(x, w_h, w_h2, w_o, p_drop_input, p_drop_hidden):
    x_drop = dropout(x, p_drop_input)
    h = rectify(x_drop @ w_h)
    h_drop = dropout(h, p_drop_hidden)
    h2 = rectify(h @ w_h2)
    h2_drop = dropout(h2, p_drop_hidden)
    pre_softmax = h2 @ w_o
    return pre_softmax

# %%
#training and testing new dropout model
# initialize weights

# input shape is (B, 784)
w_h = init_weights((784, 625))
# hidden layer with 625 neurons
w_h2 = init_weights((625, 625))
# hidden layer with 625 neurons
w_o = init_weights((625, 10))
# output shape is (B, 10)

optimizer = RMSprop(params=[w_h, w_h2, w_o])


n_epochs = 100
p_drop_input = 0.5
p_drop_hidden = 0.5

train_loss = []
test_loss = []

# put this into a training loop over 100 epochs
for epoch in range(n_epochs + 1):
    train_loss_this_epoch = []
    for idx, batch in enumerate(train_dataloader):
        x, y = batch

        # our model requires flattened input
        x = x.reshape(batch_size, 784)
        # feed input through model
        noise_py_x = dropout_model(x, w_h, w_h2, w_o, p_drop_input, p_drop_hidden)

        # reset the gradient
        optimizer.zero_grad()

        # the cross-entropy loss function already contains the softmax
        loss = cross_entropy(noise_py_x, y, reduction="mean")

        train_loss_this_epoch.append(float(loss))

        # compute the gradient
        loss.backward()
        # update weights
        optimizer.step()

    train_loss.append(np.mean(train_loss_this_epoch))

    # test periodically
    if epoch % 10 == 0:
        print(f"Epoch: {epoch}")
        print(f"Mean Train Loss: {train_loss[-1]:.2e}")
        test_loss_this_epoch = []

        # no need to compute gradients for validation
        with torch.no_grad():
            for idx, batch in enumerate(test_dataloader):
                x, y = batch
                x = x.reshape(batch_size, 784)
                noise_py_x = dropout_model(x, w_h, w_h2, w_o, 0, 0)

                loss = cross_entropy(noise_py_x, y, reduction="mean")
                test_loss_this_epoch.append(float(loss))

        test_loss.append(np.mean(test_loss_this_epoch))

        print(f"Mean Test Loss:  {test_loss[-1]:.2e}")

plt.plot(np.arange(n_epochs + 1), train_loss, label="Train")
plt.plot(np.arange(1, n_epochs + 2, 10), test_loss, label="Test")
plt.title("Train and Test Loss over Training")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
# Out:
# Epoch: 0
# Mean Train Loss: 4.92e-01
# Mean Test Loss:  2.07e-01
# Epoch: 10
# Mean Train Loss: 2.00e-01
# Mean Test Loss:  1.64e-01
# Epoch: 20
# Mean Train Loss: 1.45e-01
# Mean Test Loss:  3.24e-01
# Epoch: 30
# Mean Train Loss: 1.08e-01
# Mean Test Loss:  4.56e-01
# Epoch: 40
# Mean Train Loss: 5.23e-02
# Mean Test Loss:  3.49e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-82e055a8b243> in <module>
#      40
#      41         # compute the gradient
# ---> 42         loss.backward()
#      43         # update weights
#      44         optimizer.step()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# Epoch: 0
# Mean Train Loss: 3.94e-01
# Mean Test Loss:  3.18e-01
# Epoch: 10
# Mean Train Loss: 1.45e-01
# Mean Test Loss:  2.48e-01
# Epoch: 20
# Mean Train Loss: 9.26e-02
# Mean Test Loss:  4.87e-01
# Epoch: 30
# Mean Train Loss: 7.34e-02
# Mean Test Loss:  5.96e-01
# Epoch: 40
# Mean Train Loss: 5.43e-02
# Mean Test Loss:  6.56e-01
# Epoch: 50
# Mean Train Loss: 3.46e-02
# Mean Test Loss:  7.29e-01

# %% [markdown]
# Dropout "disables" a subset of neurons in the network with a certain probability (here taken 0.25 and 0.5) during the training process; the subset changes during each training epoch.
#
# The neurons that are still active cannot rely on their disabled neighbours and learn to be robust w.r.t. missing inputs; subtle co-adaptations of several neurons cannot occur which reduces overfitting.
#
# The network without dropout overfits a lot (test error increases basically from the start whereas training error goes down); the dropout model

# %% [markdown]
# # 3 Parametric ReLU

# %%
def PRelu(X,a):
  neg_val = torch.min(torch.zeros_like(X), X)
  add = neg_val * a
  return rectify(X) + add

def init_a(dims):
  a = torch.zeros(size = dims)
  #allow PyTorch to optimize a
  a.requires_grad = True
  return a

# %%
def prelu_model(x, w_h, w_h2, w_o, p_drop_input, p_drop_hidden, a_1, a_2):
    x_drop = dropout(x, p_drop_input)
    h = PRelu(x_drop @ w_h, a_1)
    h_drop = dropout(h, p_drop_hidden)
    h2 = PRelu(h @ w_h2, a_2)
    h2_drop = dropout(h2, p_drop_hidden)
    pre_softmax = h2 @ w_o
    return pre_softmax

# %%
#training and testing new PReLU model
# initialize weights

# input shape is (B, 784)
w_h = init_weights((784, 625))
# hidden layer with 625 neurons
w_h2 = init_weights((625, 625))
# hidden layer with 625 neurons
w_o = init_weights((625, 10))
# output shape is (B, 10)
a_1 = init_a((batch_size, 625))
a_2 = init_a((batch_size, 625))

optimizer = RMSprop(params=[w_h, w_h2, w_o, a_1, a_2])

n_epochs = 100
p_drop_input = 0.5
p_drop_hidden = 0.5

train_loss = []
test_loss = []


# put this into a training loop over 100 epochs
for epoch in range(n_epochs + 1):
    train_loss_this_epoch = []
    for idx, batch in enumerate(train_dataloader):
        x, y = batch

        # our model requires flattened input
        x = x.reshape(batch_size, 784)
        # feed input through model
        noise_py_x = prelu_model(x, w_h, w_h2, w_o, p_drop_input, p_drop_hidden, a_1, a_2)

        # reset the gradient
        optimizer.zero_grad()

        # the cross-entropy loss function already contains the softmax
        loss = cross_entropy(noise_py_x, y, reduction="mean")

        train_loss_this_epoch.append(float(loss))

        # compute the gradient
        loss.backward()
        # update weights
        optimizer.step()

    train_loss.append(np.mean(train_loss_this_epoch))

    # test periodically
    if epoch % 10 == 0:
        print(f"Epoch: {epoch}")
        print(f"Mean Train Loss: {train_loss[-1]:.2e}")
        test_loss_this_epoch = []

        # no need to compute gradients for validation
        with torch.no_grad():
            for idx, batch in enumerate(test_dataloader):
                x, y = batch
                x = x.reshape(batch_size, 784)
                noise_py_x = dropout_model(x, w_h, w_h2, w_o, 0, 0)

                loss = cross_entropy(noise_py_x, y, reduction="mean")
                test_loss_this_epoch.append(float(loss))

        test_loss.append(np.mean(test_loss_this_epoch))

        print(f"Mean Test Loss:  {test_loss[-1]:.2e}")

plt.plot(np.arange(n_epochs + 1), train_loss, label="Train")
plt.plot(np.arange(1, n_epochs + 2, 10), test_loss, label="Test")
plt.title("Train and Test Loss over Training")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
# Out:
# Epoch: 0
# Mean Train Loss: 5.34e-01
# Mean Test Loss:  1.80e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-c5b6e1e5e349> in <module>
#      42
#      43         # compute the gradient
# ---> 44         loss.backward()
#      45         # update weights
#      46         optimizer.step()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# # 4.1 Create a convolutional network

# %%
from torch.nn.functional import conv2d, max_pool2d

# %%
trainX = trainX.reshape(-1, 1, 28, 28) #training data
testX = testX.reshape(-1, 1, 28,28)

# %%
def convnet_model(X, w_conv1, w_conv2, w_conv3, w_h2, w_o, p_drop_input, p_drop_hidden):
    x_drop = dropout(x, p_drop_input)

    conv1 = rectify(conv2d(x_drop, w_conv1))
    maxpool1 = max_pool2d(conv1, (2,2))
    drop1 = dropout(maxpool1, p_drop_hidden)

    conv2 = rectify(conv2d(drop1, w_conv2))
    maxpool2 = max_pool2d(conv2, (2,2))
    drop2 = dropout(maxpool2, p_drop_hidden)

    conv3 = rectify(conv2d(drop2, w_conv3))
    maxpool3 = max_pool2d(conv3, (2,2))
    drop3 = dropout(maxpool3, p_drop_hidden)

    h2 = rectify(torch.reshape(drop3, (batch_size, 128)) @ w_h2)
    h2_drop = dropout(h2, p_drop_hidden)
    pre_softmax = h2 @ w_o
    return pre_softmax

# %% [markdown]
# # 4.2 Application of Convolutional network

# %%
# Initializing weights 

w_conv1 = init_weights((32, 1, 5, 5))
w_conv2 = init_weights((64, 32, 5, 5))
w_conv3 = init_weights((128, 64, 2, 2))
w_h2 = init_weights((128, 625))
w_o = init_weights((625, 10))

cnn_optimizer = RMSprop(params=[w_conv1, w_conv2, w_conv3, w_h2, w_o])

n_epochs = 10

cnn_train_loss = []
cnn_test_loss = []

p_drop_input_cnn = 0.05
p_drop_hidden_cnn = 0.05

# put this into a training loop over 10 epochs
for epoch in range(n_epochs + 1):
    train_loss_this_epoch = []
    for idx, batch in enumerate(train_dataloader):
        x, y = batch
        x = x.view(batch_size, 1, 28, 28) 

        # feed input through model
        noise_py_x = convnet_model(x, w_conv1, w_conv2, w_conv3, w_h2, w_o, p_drop_input_cnn, p_drop_hidden_cnn)

        # reset the gradient
        cnn_optimizer.zero_grad()

        # the cross-entropy loss function already contains the softmax
        loss = cross_entropy(noise_py_x, y, reduction="mean")

        train_loss_this_epoch.append(float(loss))

        # compute the gradient
        loss.backward()
        # update weights
        cnn_optimizer.step()

    cnn_train_loss.append(np.mean(train_loss_this_epoch))

    # test periodically
    if epoch % 2 == 0:
        print(f"Epoch: {epoch}")
        print(f"Mean Train Loss: {cnn_train_loss[-1]:.2e}")
        test_loss_this_epoch = []

        # no need to compute gradients for validation
        with torch.no_grad():
            for idx, batch in enumerate(test_dataloader):
                x, y = batch
                x = x.view(-1, 1, 28, 28)
                noise_py_x = convnet_model(x, w_conv1, w_conv2, w_conv3, w_h2, w_o, 0, 0)

                loss = cross_entropy(noise_py_x, y, reduction="mean")
                test_loss_this_epoch.append(float(loss))

        cnn_test_loss.append(np.mean(test_loss_this_epoch))

        print(f"Mean Test Loss:  {cnn_test_loss[-1]:.2e}")

plt.plot(np.arange(n_epochs + 1), cnn_train_loss, label="Train")
plt.plot(np.arange(1, n_epochs + 2, 10), cnn_test_loss, label="Test")
plt.title("Train and Test Loss over Training")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-116-ebc4904b0fb4> in <module>
#      36
#      37         # compute the gradient
# ---> 38         loss.backward()
#      39         # update weights
#      40         cnn_optimizer.step()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
examples = enumerate(test_dataloader)
batch_idx, (example_data, example_targets) = next(examples)
example = example_data[21]
# Out:
# Traceback (most recent call last):
#   File "/Users/szymonszmajdzinski/opt/anaconda3/lib/python3.8/multiprocessing/queues.py", line 245, in _feed
#     send_bytes(obj)
#   File "/Users/szymonszmajdzinski/opt/anaconda3/lib/python3.8/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/Users/szymonszmajdzinski/opt/anaconda3/lib/python3.8/multiprocessing/connection.py", line 411, in _send_bytes
#     self._send(header + buf)
#   File "/Users/szymonszmajdzinski/opt/anaconda3/lib/python3.8/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

plt.imshow(example_data[21][0], cmap='gray')
plt.title("Ground Truth: {}".format(example_targets[21]))
# Out:
# Text(0.5, 1.0, 'Ground Truth: 6')

# %%
example = example.reshape((1, 1, 28, 28))
fig, axes = plt.subplots(nrows=2, ncols=3)

for i in range(3): 
    plt.subplot(2,3,i+1)
    if i == 0:
        plt.ylabel('Convolution')
    conv_example = conv2d(example, w_conv1[i].reshape((1, 1, 5, 5)))
    plt.imshow(conv_example[0][0].detach().numpy(), cmap='gray')
    plt.subplot(2,3,i + 4)
    plt.imshow(w_conv1[i][0].detach().numpy(), cmap = 'gray')
    
plt.tight_layout()

# %%
def convnet_model_modified(X, w_conv1, w_conv2, w_conv3, w_h2, w_o, p_drop_input, p_drop_hidden):
    x_drop = dropout(x, p_drop_input)

    conv1 = rectify(conv2d(x_drop, w_conv1))
    maxpool1 = max_pool2d(conv1, (2,2))
    drop1 = dropout(maxpool1, p_drop_hidden)

    conv2 = rectify(conv2d(drop1, w_conv2))
    maxpool2 = max_pool2d(conv2, (2,2))
    drop2 = dropout(maxpool2, p_drop_hidden)

    conv3 = rectify(conv2d(drop2, w_conv3))
    maxpool3 = max_pool2d(conv3, (2,2))
    drop3 = dropout(maxpool3, p_drop_hidden)

    h2 = rectify(torch.reshape(drop3, (batch_size, 128)) @ w_h2)
    h2_drop = dropout(h2, p_drop_hidden)
    pre_softmax = h2 @ w_o
    return pre_softmax

# %%
w_conv1 = init_weights((32, 1, 8, 8))
w_conv2 = init_weights((64, 32, 5, 5))
w_conv3 = init_weights((128, 64, 2, 2))
w_h2 = init_weights((128, 625))
w_o = init_weights((625, 10))

cnn_optimizer = RMSprop(params=[w_conv1, w_conv2, w_conv3, w_h2, w_o])

n_epochs = 10

cnn_train_loss = []
cnn_test_loss = []

p_drop_input_cnn = 0.05
p_drop_hidden_cnn = 0.05

# put this into a training loop over 10 epochs
for epoch in range(n_epochs + 1):
    train_loss_this_epoch = []
    for idx, batch in enumerate(train_dataloader):
        x, y = batch
        x = x.view(batch_size, 1, 28, 28)

        # feed input through model
        noise_py_x = convnet_model_modified(x, w_conv1, w_conv2, w_conv3, w_h2, w_o, p_drop_input_cnn, p_drop_hidden_cnn)

        # reset the gradient
        cnn_optimizer.zero_grad()

        # the cross-entropy loss function already contains the softmax
        loss = cross_entropy(noise_py_x, y, reduction="mean")

        train_loss_this_epoch.append(float(loss))

        # compute the gradient
        loss.backward()
        # update weights
        cnn_optimizer.step()

    cnn_train_loss.append(np.mean(train_loss_this_epoch))

    # test periodically
    if epoch % 2 == 0:
        print(f"Epoch: {epoch}")
        print(f"Mean Train Loss: {cnn_train_loss[-1]:.2e}")
        test_loss_this_epoch = []

        # no need to compute gradients for validation
        with torch.no_grad():
            for idx, batch in enumerate(test_dataloader):
                x, y = batch
                x = x.view(-1, 1, 28, 28)
                noise_py_x = convnet_model(x, w_conv1, w_conv2, w_conv3, w_h2, w_o, 0, 0)

                loss = cross_entropy(noise_py_x, y, reduction="mean")
                test_loss_this_epoch.append(float(loss))

        cnn_test_loss.append(np.mean(test_loss_this_epoch))

        print(f"Mean Test Loss:  {cnn_test_loss[-1]:.2e}")

plt.plot(np.arange(n_epochs + 1), cnn_train_loss, label="Train")
plt.plot(np.arange(1, n_epochs + 2, 10), cnn_test_loss, label="Test")
plt.title("Train and Test Loss over Training")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
# Out:
# Epoch: 0
# Mean Train Loss: 1.14e+00
# Mean Test Loss:  2.27e-01
# Epoch: 2
# Mean Train Loss: 1.36e-01
# Mean Test Loss:  1.49e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-178a032eb539> in <module>
#      23
#      24         # feed input through model
# ---> 25         noise_py_x = convnet_model_modified(x, w_conv1, w_conv2, w_conv3, w_h2, w_o, p_drop_input_cnn, p_drop_hidden_cnn)
#      26
#      27         # reset the gradient
#
# <ipython-input-103-f3ff4a9414df> in convnet_model_modified(X, w_conv1, w_conv2, w_conv3, w_h2, w_o, p_drop_input, p_drop_hidden)
#       2     x_drop = dropout(x, p_drop_input)
#       3
# ----> 4     conv1 = rectify(conv2d(x_drop, w_conv1))
#       5     maxpool1 = max_pool2d(conv1, (2,2))
#       6     drop1 = dropout(maxpool1, p_drop_hidden)
#
# KeyboardInterrupt:

# %%
fig = plt.figure()
for i in range(3): 
    plt.subplot(2,3,i+1)
    conv_example = conv2d(example, w_conv1[i].reshape((1, 1, 5, 5)))
    plt.imshow(conv_example[0][0].detach().numpy(), cmap='gray')
    plt.subplot(2,3,i + 4)
    plt.imshow(w_conv1[i][0].detach().numpy(), cmap = 'gray')
    
    plt.tight_layout()
